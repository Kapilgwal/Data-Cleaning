# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data_full_dirty.csv')
df
# Out:
#       Unnamed: 0                       name  LTE            year  \
# 0              0     Acer Chromebook Tab 10    0     2018, March
# 1              1         Acer Iconia Talk S    1    2016, August
# 2              2        Acer Liquid Z6 Plus    1    2016, August
# 3              3             Acer Liquid Z6    1    2016, August
# 4              4  Acer Iconia Tab 10 A3-A40    0     2016, April
# ...          ...                        ...  ...             ...
# 3024        3024          ZTE nubia N1 lite    1  2017, February
# 3025        3025          ZTE Blade V8 Mini    1  2017, February
# 3026        3026          ZTE Blade V8 Lite    1  2017, February
# 3027        3027          ZTE Blade A2 Plus    1  2017, February
# 3028        3028                ZTE Hawkeye    1   2017, January
#
#                  weight                                display_type  \
# 0     544.3 g (1.20 lb)  IPS LCD capacitive touchscreen, 16M colors
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3029 entries, 0 to 3028
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    3029 non-null   int64
#  1   name          3029 non-null   object
#  2   LTE           3029 non-null   int64
#  3   year          3027 non-null   object
#  4   weight        2989 non-null   object
#  5   display_type  3026 non-null   object
#  6   screen_size   2712 non-null   object
#  7   ppi           3023 non-null   object
#  8   cpu_ghz       2213 non-null   object
#  9   ram           2626 non-null   object
#  10  internal      2626 non-null   object
#  11  camera        3026 non-null   object
#  12  front_cam     2716 non-null   object
#  13  blth_v        3028 non-null   object
#  14  battery       3028 non-null   object
#  15  price         1633 non-null   object
# dtypes: int64(2), object(14)
# memory usage: 378.8+ KB

# %%
df.drop(columns = ['Unnamed: 0'], axis=0,inplace=True)

# %%
df
# Out:
#                            name  LTE            year             weight  \
# 0        Acer Chromebook Tab 10    0     2018, March  544.3 g (1.20 lb)
# 1            Acer Iconia Talk S    1    2016, August    260 g (9.17 oz)
# 2           Acer Liquid Z6 Plus    1    2016, August    169 g (5.96 oz)
# 3                Acer Liquid Z6    1    2016, August    126 g (4.44 oz)
# 4     Acer Iconia Tab 10 A3-A40    0     2016, April                  -
# ...                         ...  ...             ...                ...
# 3024          ZTE nubia N1 lite    1  2017, February    171 g (6.03 oz)
# 3025          ZTE Blade V8 Mini    1  2017, February    141 g (4.97 oz)
# 3026          ZTE Blade V8 Lite    1  2017, February    136 g (4.80 oz)
# 3027          ZTE Blade A2 Plus    1  2017, February    189 g (6.67 oz)
# 3028                ZTE Hawkeye    1   2017, January                  -
#
#                                     display_type  \
# 0     IPS LCD capacitive touchscreen, 16M colors
# ...

# %%
def company_name(text):
    arr = text.split(' ')
    return arr[0]

# %%
df['company'] = df['name'].apply(company_name)

# %%
df
# Out:
#                            name  LTE            year             weight  \
# 0        Acer Chromebook Tab 10    0     2018, March  544.3 g (1.20 lb)
# 1            Acer Iconia Talk S    1    2016, August    260 g (9.17 oz)
# 2           Acer Liquid Z6 Plus    1    2016, August    169 g (5.96 oz)
# 3                Acer Liquid Z6    1    2016, August    126 g (4.44 oz)
# 4     Acer Iconia Tab 10 A3-A40    0     2016, April                  -
# ...                         ...  ...             ...                ...
# 3024          ZTE nubia N1 lite    1  2017, February    171 g (6.03 oz)
# 3025          ZTE Blade V8 Mini    1  2017, February    141 g (4.97 oz)
# 3026          ZTE Blade V8 Lite    1  2017, February    136 g (4.80 oz)
# 3027          ZTE Blade A2 Plus    1  2017, February    189 g (6.67 oz)
# 3028                ZTE Hawkeye    1   2017, January                  -
#
#                                     display_type  \
# 0     IPS LCD capacitive touchscreen, 16M colors
# ...

# %%
def fetch_year(text):
    text = str(text)
    arr = text.split(',')
    return str(arr[0])

# %%
fetch_year('2019,April')
# Out:
# '2019'

# %%
df['year_rel'] = df['year'].apply(fetch_year)

# %%
df
# Out:
#                            name  LTE            year             weight  \
# 0        Acer Chromebook Tab 10    0     2018, March  544.3 g (1.20 lb)
# 1            Acer Iconia Talk S    1    2016, August    260 g (9.17 oz)
# 2           Acer Liquid Z6 Plus    1    2016, August    169 g (5.96 oz)
# 3                Acer Liquid Z6    1    2016, August    126 g (4.44 oz)
# 4     Acer Iconia Tab 10 A3-A40    0     2016, April                  -
# ...                         ...  ...             ...                ...
# 3024          ZTE nubia N1 lite    1  2017, February    171 g (6.03 oz)
# 3025          ZTE Blade V8 Mini    1  2017, February    141 g (4.97 oz)
# 3026          ZTE Blade V8 Lite    1  2017, February    136 g (4.80 oz)
# 3027          ZTE Blade A2 Plus    1  2017, February    189 g (6.67 oz)
# 3028                ZTE Hawkeye    1   2017, January                  -
#
#                                     display_type  \
# 0     IPS LCD capacitive touchscreen, 16M colors
# ...

# %%
def fetch_month(text):
    text = str(text)
    arr = text.split(',')
    
    if(len(arr) > 1):
        return str(arr[1])
    
    else:
        return "nan"

# %%
df['month'] = df['year'].apply(fetch_month)

# %%
df
# Out:
#                            name  LTE            year             weight  \
# 0        Acer Chromebook Tab 10    0     2018, March  544.3 g (1.20 lb)
# 1            Acer Iconia Talk S    1    2016, August    260 g (9.17 oz)
# 2           Acer Liquid Z6 Plus    1    2016, August    169 g (5.96 oz)
# 3                Acer Liquid Z6    1    2016, August    126 g (4.44 oz)
# 4     Acer Iconia Tab 10 A3-A40    0     2016, April                  -
# ...                         ...  ...             ...                ...
# 3024          ZTE nubia N1 lite    1  2017, February    171 g (6.03 oz)
# 3025          ZTE Blade V8 Mini    1  2017, February    141 g (4.97 oz)
# 3026          ZTE Blade V8 Lite    1  2017, February    136 g (4.80 oz)
# 3027          ZTE Blade A2 Plus    1  2017, February    189 g (6.67 oz)
# 3028                ZTE Hawkeye    1   2017, January                  -
#
#                                     display_type  \
# 0     IPS LCD capacitive touchscreen, 16M colors
# ...

# %%
df['company'].unique()
# Out:
# array(['Acer', 'alcatel', 'Allview', 'Amazon', 'Amoi', 'Apple', 'Archos',
#        'Asus', 'AT&T;', 'Benefon', 'BenQ', 'BenQ-Siemens', 'Bird',
#        'BlackBerry', 'Blackview', 'BLU', 'Bosch', 'BQ', 'Casio', 'Cat',
#        'Celkon', 'Chea', 'Coolpad', 'Dell', 'Emporia', 'Energizer',
#        'Ericsson', 'Eten', 'Fujitsu', 'Garmin-Asus', 'Gigabyte', 'Gionee',
#        'Google', 'Haier', 'HP', 'HTC', 'Huawei', 'i-mate', 'i-mobile',
#        'Icemobile', 'Infinix', 'Innostream', 'iNQ', 'Intex', 'Jolla',
#        'Karbonn', 'Kyocera', 'Lava', 'LeEco', 'Lenovo', 'LG', 'Maxon',
#        'Maxwest', 'Meizu', 'Micromax', 'Microsoft', 'Mitac', 'Mitsubishi',
#        'Modu', 'Motorola', 'MWg', 'NEC', 'Neonode', 'NIU', 'Nokia',
#        'Nvidia', 'O2', 'OnePlus', 'Oppo', 'Orange', 'Palm', 'Panasonic',
#        'Pantech', 'Parla', 'Philips', 'Plum', 'Posh', 'Prestigio',
#        'QMobile', 'Qtek', 'Razer', 'Realme', 'Sagem', 'Samsung', 'Sendo',
# ...

# %%
df
# Out:
#                            name  LTE            year             weight  \
# 0        Acer Chromebook Tab 10    0     2018, March  544.3 g (1.20 lb)
# 1            Acer Iconia Talk S    1    2016, August    260 g (9.17 oz)
# 2           Acer Liquid Z6 Plus    1    2016, August    169 g (5.96 oz)
# 3                Acer Liquid Z6    1    2016, August    126 g (4.44 oz)
# 4     Acer Iconia Tab 10 A3-A40    0     2016, April                  -
# ...                         ...  ...             ...                ...
# 3024          ZTE nubia N1 lite    1  2017, February    171 g (6.03 oz)
# 3025          ZTE Blade V8 Mini    1  2017, February    141 g (4.97 oz)
# 3026          ZTE Blade V8 Lite    1  2017, February    136 g (4.80 oz)
# 3027          ZTE Blade A2 Plus    1  2017, February    189 g (6.67 oz)
# 3028                ZTE Hawkeye    1   2017, January                  -
#
#                                     display_type  \
# 0     IPS LCD capacitive touchscreen, 16M colors
# ...

# %%
def fetch_colors(text):
    text = str(text)
    text = text.split(',')
    
    if(len(text) > 1):
        return text[1]
    
    else:
        return "nan"
    
text = 'IPS LCD capacitive touchscreen, 16M colors'
fetch_colors(text)
df['colors'] = df['display_type'].apply(fetch_colors)

# %%
df
# Out:
#                            name  LTE            year             weight  \
# 0        Acer Chromebook Tab 10    0     2018, March  544.3 g (1.20 lb)
# 1            Acer Iconia Talk S    1    2016, August    260 g (9.17 oz)
# 2           Acer Liquid Z6 Plus    1    2016, August    169 g (5.96 oz)
# 3                Acer Liquid Z6    1    2016, August    126 g (4.44 oz)
# 4     Acer Iconia Tab 10 A3-A40    0     2016, April                  -
# ...                         ...  ...             ...                ...
# 3024          ZTE nubia N1 lite    1  2017, February    171 g (6.03 oz)
# 3025          ZTE Blade V8 Mini    1  2017, February    141 g (4.97 oz)
# 3026          ZTE Blade V8 Lite    1  2017, February    136 g (4.80 oz)
# 3027          ZTE Blade A2 Plus    1  2017, February    189 g (6.67 oz)
# 3028                ZTE Hawkeye    1   2017, January                  -
#
#                                     display_type  \
# 0     IPS LCD capacitive touchscreen, 16M colors
# ...

# %%
df['colors'].unique()
# Out:
# array([' 16M colors', 'nan', ' 256K colors (65K effective)',
#        ' 65K colors', ' 256K colors', ' mono', ' 256Kcolors',
#        ' 4K colors', ' capacitive touchscreen', ' 260K colors',
#        ' 4096 colors', ' 256 colors', ' monochrome graphics',
#        ' 256K colors (65K effective colors)', ' 16M', ' 4 shades',
#        ' 65k colors', ' 16 shades', '  256K colors', ' 26M colors',
#        ' 16M colors (65K effective)', ' monochrome', ' 32K colors'],
#       dtype=object)

# %%
def fetch_screen(text):
    text = str(text)
    text = text.split(',')
    
    return text[0]
df['screen_size_inch'] = df['screen_size'].apply(fetch_screen)

# %%
def fetch_length(text):
    text = str(text)
    text = text.split(' ')
    return text[0]

df['screen_size_inch'] = df['screen_size_inch'].apply(fetch_length)

# %%
df
# Out:
#                            name  LTE            year             weight  \
# 0        Acer Chromebook Tab 10    0     2018, March  544.3 g (1.20 lb)
# 1            Acer Iconia Talk S    1    2016, August    260 g (9.17 oz)
# 2           Acer Liquid Z6 Plus    1    2016, August    169 g (5.96 oz)
# 3                Acer Liquid Z6    1    2016, August    126 g (4.44 oz)
# 4     Acer Iconia Tab 10 A3-A40    0     2016, April                  -
# ...                         ...  ...             ...                ...
# 3024          ZTE nubia N1 lite    1  2017, February    171 g (6.03 oz)
# 3025          ZTE Blade V8 Mini    1  2017, February    141 g (4.97 oz)
# 3026          ZTE Blade V8 Lite    1  2017, February    136 g (4.80 oz)
# 3027          ZTE Blade A2 Plus    1  2017, February    189 g (6.67 oz)
# 3028                ZTE Hawkeye    1   2017, January                  -
#
#                                     display_type  \
# 0     IPS LCD capacitive touchscreen, 16M colors
# ...

# %%
def fetch_camera(text):
    text = str(text)
    text = text.split(',')
    return text[0]
fetch_camera('13 MP, PDAF')
df['camera_size'] = df['camera'].apply(fetch_camera)

# %%
df
# Out:
#                            name  LTE            year             weight  \
# 0        Acer Chromebook Tab 10    0     2018, March  544.3 g (1.20 lb)
# 1            Acer Iconia Talk S    1    2016, August    260 g (9.17 oz)
# 2           Acer Liquid Z6 Plus    1    2016, August    169 g (5.96 oz)
# 3                Acer Liquid Z6    1    2016, August    126 g (4.44 oz)
# 4     Acer Iconia Tab 10 A3-A40    0     2016, April                  -
# ...                         ...  ...             ...                ...
# 3024          ZTE nubia N1 lite    1  2017, February    171 g (6.03 oz)
# 3025          ZTE Blade V8 Mini    1  2017, February    141 g (4.97 oz)
# 3026          ZTE Blade V8 Lite    1  2017, February    136 g (4.80 oz)
# 3027          ZTE Blade A2 Plus    1  2017, February    189 g (6.67 oz)
# 3028                ZTE Hawkeye    1   2017, January                  -
#
#                                     display_type  \
# 0     IPS LCD capacitive touchscreen, 16M colors
# ...

# %%
def fetch_cam_size(text):
    text = str(text)
    text = text.split(' ')
    return text[0]

df['camera_size'] = df['camera_size'].apply(fetch_cam_size)

# %%
df['camera_size'].unique()
# Out:
# array(['5', '13', '8', '21', '2', '12', 'nan', '16', 'No', '1.3', '3.15',
#        'VGA', '20.7', '13.4', '23', 'CIF', '18', '24', '12.2', '12.3',
#        'Yes', '0.9', '20', '20.2', '48', '40', '3.2', '1.2', '14', '10',
#        '1', '6.7', 'Motorized', 'Daul:', '12.6', '22.6', '19', '21.5',
#        '8.1', 'QVGA', '13.2', '2.26', '3', '0.8', '4'], dtype=object)

# %%
def fetch_ram(text):
    text = str(text)
    text = text.split(',')
    return text[0]

# %%
df['ram'] = df['ram'].apply(fetch_ram)

# %%
df['ram']
# Out:
# 0             32 GB
# 1          16/32 GB
# 2             32 GB
# 3              8 GB
# 4       16/32/64 GB
#            ...
# 3024          16 GB
# 3025          16 GB
# 3026          16 GB
# 3027          32 GB
# 3028          32 GB
# Name: ram, Length: 3029, dtype: object

# %%
df
# Out:
#                            name  LTE            year             weight  \
# 0        Acer Chromebook Tab 10    0     2018, March  544.3 g (1.20 lb)
# 1            Acer Iconia Talk S    1    2016, August    260 g (9.17 oz)
# 2           Acer Liquid Z6 Plus    1    2016, August    169 g (5.96 oz)
# 3                Acer Liquid Z6    1    2016, August    126 g (4.44 oz)
# 4     Acer Iconia Tab 10 A3-A40    0     2016, April                  -
# ...                         ...  ...             ...                ...
# 3024          ZTE nubia N1 lite    1  2017, February    171 g (6.03 oz)
# 3025          ZTE Blade V8 Mini    1  2017, February    141 g (4.97 oz)
# 3026          ZTE Blade V8 Lite    1  2017, February    136 g (4.80 oz)
# 3027          ZTE Blade A2 Plus    1  2017, February    189 g (6.67 oz)
# 3028                ZTE Hawkeye    1   2017, January                  -
#
#                                     display_type  \
# 0     IPS LCD capacitive touchscreen, 16M colors
# ...

# %%
def fetch_bluetooth(text):
    text = str(text)
    text = text.split(',')
    return text[0]

df['bluetooth'] = df['blth_v'].apply(fetch_bluetooth)

# %%
df
# Out:
#                            name  LTE            year             weight  \
# 0        Acer Chromebook Tab 10    0     2018, March  544.3 g (1.20 lb)
# 1            Acer Iconia Talk S    1    2016, August    260 g (9.17 oz)
# 2           Acer Liquid Z6 Plus    1    2016, August    169 g (5.96 oz)
# 3                Acer Liquid Z6    1    2016, August    126 g (4.44 oz)
# 4     Acer Iconia Tab 10 A3-A40    0     2016, April                  -
# ...                         ...  ...             ...                ...
# 3024          ZTE nubia N1 lite    1  2017, February    171 g (6.03 oz)
# 3025          ZTE Blade V8 Mini    1  2017, February    141 g (4.97 oz)
# 3026          ZTE Blade V8 Lite    1  2017, February    136 g (4.80 oz)
# 3027          ZTE Blade A2 Plus    1  2017, February    189 g (6.67 oz)
# 3028                ZTE Hawkeye    1   2017, January                  -
#
#                                     display_type  \
# 0     IPS LCD capacitive touchscreen, 16M colors
# ...

# %%
df['internal'] = df['internal'].apply(fetch_ram)

# %%
df
# Out:
#                            name  LTE            year             weight  \
# 0        Acer Chromebook Tab 10    0     2018, March  544.3 g (1.20 lb)
# 1            Acer Iconia Talk S    1    2016, August    260 g (9.17 oz)
# 2           Acer Liquid Z6 Plus    1    2016, August    169 g (5.96 oz)
# 3                Acer Liquid Z6    1    2016, August    126 g (4.44 oz)
# 4     Acer Iconia Tab 10 A3-A40    0     2016, April                  -
# ...                         ...  ...             ...                ...
# 3024          ZTE nubia N1 lite    1  2017, February    171 g (6.03 oz)
# 3025          ZTE Blade V8 Mini    1  2017, February    141 g (4.97 oz)
# 3026          ZTE Blade V8 Lite    1  2017, February    136 g (4.80 oz)
# 3027          ZTE Blade A2 Plus    1  2017, February    189 g (6.67 oz)
# 3028                ZTE Hawkeye    1   2017, January                  -
#
#                                     display_type  \
# 0     IPS LCD capacitive touchscreen, 16M colors
# ...

# %%
def fetch_resolution(text):
    text = str(text)
    text = text.split(',')
    return text[0]

df['resolution'] = df['ppi'].apply(fetch_resolution)

# %%
df['resolution'].unique()
# Out:
# array(['1536 x 2048 pixels', '720 x 1280 pixels', '1080 x 1920 pixels',
#        '1920 x 1200 pixels', '480 x 854 pixels', '800 x 1280 pixels',
#        '1280 x 800 pixels', '480 x 800 pixels', '540 x 960 pixels',
#        '1200 x 1920 pixels', '600 x 1024 pixels', '1080 x 2180 pixels',
#        '720 x 1500 pixels (~268 ppi density)', '720 x 1440 pixels',
#        '1080 x 2160 pixels', '480 x 960 pixels', '1024 x 600 pixels',
#        '1440 x 2560 pixels', '96 x 64 pixels', '240 x 240 pixels',
#        '720 x 1498 pixels (~293 ppi density)', '720 x 1520 pixels',
#        '1080 x 2246 pixels', '128 x 128 pixels', '2560 x 1600 pixels',
#        '240 x 320 pixels', '176 x 220 pixels (~141 ppi density)',
#        '320 x 240 pixels', '128 x 160 pixels (~114 ppi density)',
#        '204 x 320 pixels (~158 ppi density)', '240 x 320pixels',
#        '176 x 220pixels (~141 ppi density)',
#        '176 x 220 pixels (~157 ppi density)',
# ...

# %%
def fetch_processor(text):
    text = str(text)
    text = text.split(' ')
    return text[0]

df['processor_core'] = df['cpu_ghz'].apply(fetch_processor)

# %%
df
# Out:
#                            name  LTE            year             weight  \
# 0        Acer Chromebook Tab 10    0     2018, March  544.3 g (1.20 lb)
# 1            Acer Iconia Talk S    1    2016, August    260 g (9.17 oz)
# 2           Acer Liquid Z6 Plus    1    2016, August    169 g (5.96 oz)
# 3                Acer Liquid Z6    1    2016, August    126 g (4.44 oz)
# 4     Acer Iconia Tab 10 A3-A40    0     2016, April                  -
# ...                         ...  ...             ...                ...
# 3024          ZTE nubia N1 lite    1  2017, February    171 g (6.03 oz)
# 3025          ZTE Blade V8 Mini    1  2017, February    141 g (4.97 oz)
# 3026          ZTE Blade V8 Lite    1  2017, February    136 g (4.80 oz)
# 3027          ZTE Blade A2 Plus    1  2017, February    189 g (6.67 oz)
# 3028                ZTE Hawkeye    1   2017, January                  -
#
#                                     display_type  \
# 0     IPS LCD capacitive touchscreen, 16M colors
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3029 entries, 0 to 3028
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              3029 non-null   object
#  1   LTE               3029 non-null   int64
#  2   year              3027 non-null   object
#  3   weight            2989 non-null   object
#  4   display_type      3026 non-null   object
#  5   screen_size       2712 non-null   object
#  6   ppi               3023 non-null   object
#  7   cpu_ghz           2213 non-null   object
#  8   ram               3029 non-null   object
#  9   internal          3029 non-null   object
#  10  camera            3026 non-null   object
#  11  front_cam         2716 non-null   object
#  12  blth_v            3028 non-null   object
#  13  battery           3028 non-null   object
#  14  price             1633 non-null   object
#  15  company           3029 non-null   object
# ...

# %%
df['battery'].unique()
# Out:
# array(['Non-removable Li-Po 4500 mAh battery (34 Wh)',
#        'Non-removable Li-Ion 3400 mAh battery (12.92 Wh)',
#        'Non-removable Li-Po 4080 mAh battery',
#        'Removable Li-Ion 2000 mAh battery',
#        'Non-removable Li-Ion 6100 mAh battery',
#        'Removable Li-Po 4020 mAh battery',
#        'Non-removable Li-Po 3000 mAh battery',
#        'Non-removable Li-Ion 5000 mAh battery',
#        'Non-removable Li-Po 4420 mAh battery',
#        'Non-removable Li-Po 2870 mAh battery',
#        'Removable Li-Po 2000 mAh battery',
#        'Removable Li-Po 4000 mAh battery (15.2 Wh)',
#        'Removable Li-Ion 4000 mAh battery',
#        'Removable Li-Ion 2420 mAh battery',
#        'Non-removable Li-Ion 5910 mAh battery (22 Wh)',
#        'Non-removable Li-Ion 4550 mAh battery (17.2 Wh)',
#        'Non-removable Li-Po 5910 mAh battery (A3-A20-K1AY)',
#        'Non-removable Li-Po 5910 mAh battery (A3-A20FHD-K8KX)',
#        'Non-removable Li-Po 2300 mAh battery',
# ...

# %%
def fetch_battery(text):
    text = str(text)
    text = text.split(' ')
    return len(text)

df['battery_size'] = df['battery'].apply(fetch_battery)

# %%
df['weight'].sort_values(ascending=False)
# Out:
# 1477                ~ 175 g (6.17 oz)
# 2662    From 166 g to 238 g (5.86 oz)
# 2592                  998 g (2.20 lb)
# 1725                 99.8 g (3.53 oz)
# 1846                 99.5 g (3.53 oz)
#                     ...
# 2764                              NaN
# 2765                              NaN
# 2776                              NaN
# 2777                              NaN
# 2778                              NaN
# Name: weight, Length: 3029, dtype: object

# %%
def fetch_weight(text):
    text = str(text)
    text = text.split('g')
    return text[0]

df['new_weight'] = df['weight'].apply(fetch_weight)

# %%
df['new_weight'].sort_values(ascending=False)
# Out:
# 1477    ~ 175
# 140        nan
# 2754       nan
# 2252       nan
# 2778       nan
#          ...
# 1143         -
# 1145         -
# 1146         -
# 1150         -
# 3028         -
# Name: new_weight, Length: 3029, dtype: object

# %%
df['weight'] = df['new_weight']

# %%
df
# Out:
#                            name  LTE            year  weight  \
# 0        Acer Chromebook Tab 10    0     2018, March  544.3
# 1            Acer Iconia Talk S    1    2016, August    260
# 2           Acer Liquid Z6 Plus    1    2016, August    169
# 3                Acer Liquid Z6    1    2016, August    126
# 4     Acer Iconia Tab 10 A3-A40    0     2016, April       -
# ...                         ...  ...             ...     ...
# 3024          ZTE nubia N1 lite    1  2017, February    171
# 3025          ZTE Blade V8 Mini    1  2017, February    141
# 3026          ZTE Blade V8 Lite    1  2017, February    136
# 3027          ZTE Blade A2 Plus    1  2017, February    189
# 3028                ZTE Hawkeye    1   2017, January       -
#
#                                     display_type  \
# 0     IPS LCD capacitive touchscreen, 16M colors
# 1     IPS LCD capacitive touchscreen, 16M colors
# 2     IPS LCD capacitive touchscreen, 16M colors
# ...

# %%
df['ppi'].sort_values(ascending=False)
# Out:
# 675                                    Big
# 2259    98 x 67 pixels, 5 lines, 3:2 ratio
# 2268    96 x 64 pixels, 6 lines, 3:2 ratio
# 2264    96 x 64 pixels, 6 lines, 3:2 ratio
# 2267    96 x 64 pixels, 6 lines, 3:2 ratio
#                        ...
# 2252                                   NaN
# 2344                                   NaN
# 2664                                   NaN
# 2665                                   NaN
# 2667                                   NaN
# Name: ppi, Length: 3029, dtype: object

# %%
def fetch_scree_ratio(text):
    text = str(text)
    text = text.split(',')
    return text[-1]

# %%
df['screen_ratio'] = df['ppi'].apply(fetch_scree_ratio)

# %%
df['screen_ratio'].sort_values(ascending=False)
# Out:
# 2252          nan
# 2665          nan
# 828           nan
# 2667          nan
# 2664          nan
#           ...
# 1103     10 lines
# 1532     10 lines
# 1105     10 lines
# 1614     1.9 inch
# 1529      7 lines
# Name: screen_ratio, Length: 3029, dtype: object

# %%
df
# Out:
#                            name  LTE            year  weight  \
# 0        Acer Chromebook Tab 10    0     2018, March  544.3
# 1            Acer Iconia Talk S    1    2016, August    260
# 2           Acer Liquid Z6 Plus    1    2016, August    169
# 3                Acer Liquid Z6    1    2016, August    126
# 4     Acer Iconia Tab 10 A3-A40    0     2016, April       -
# ...                         ...  ...             ...     ...
# 3024          ZTE nubia N1 lite    1  2017, February    171
# 3025          ZTE Blade V8 Mini    1  2017, February    141
# 3026          ZTE Blade V8 Lite    1  2017, February    136
# 3027          ZTE Blade A2 Plus    1  2017, February    189
# 3028                ZTE Hawkeye    1   2017, January       -
#
#                                     display_type  \
# 0     IPS LCD capacitive touchscreen, 16M colors
# 1     IPS LCD capacitive touchscreen, 16M colors
# 2     IPS LCD capacitive touchscreen, 16M colors
# ...

# %%
def fetch_scree_ratio_num(text):
    text = str(text)
    if text.find('ratio') != -1:
       text = text.split('ratio')
       return text[0]
    
    else:
        return None

# %%
df['screen_ratio_num'] = df['screen_ratio'].apply(fetch_scree_ratio_num)

# %%
df
# Out:
#                            name  LTE            year  weight  \
# 0        Acer Chromebook Tab 10    0     2018, March  544.3
# 1            Acer Iconia Talk S    1    2016, August    260
# 2           Acer Liquid Z6 Plus    1    2016, August    169
# 3                Acer Liquid Z6    1    2016, August    126
# 4     Acer Iconia Tab 10 A3-A40    0     2016, April       -
# ...                         ...  ...             ...     ...
# 3024          ZTE nubia N1 lite    1  2017, February    171
# 3025          ZTE Blade V8 Mini    1  2017, February    141
# 3026          ZTE Blade V8 Lite    1  2017, February    136
# 3027          ZTE Blade A2 Plus    1  2017, February    189
# 3028                ZTE Hawkeye    1   2017, January       -
#
#                                     display_type  \
# 0     IPS LCD capacitive touchscreen, 16M colors
# 1     IPS LCD capacitive touchscreen, 16M colors
# 2     IPS LCD capacitive touchscreen, 16M colors
# ...

# %%
df['screen_ratio_num'].unique()
# Out:
# array([' 4:3 ', ' 16:9 ', ' 16:10 ', ' 5:3 ', ' 18:9 ', None, ' 3:2 ',
#        ' 1:1 ', ' 19:9 ', ' 18.7:9 ', ' 19.5:9 ', ' 17:9 ', ' 18.5:9 '],
#       dtype=object)

# %%
def fetch_ppi(text):
   text = str(text)
   if text.find('~') != -1:
      text = text.split('~')
      return text[1]
   else:
      return None

# %%
df['ppi_density'] = df['ppi'].apply(fetch_ppi)

# %%
df['ppi_density'].unique()
# Out:
# array(['264 ppi density)', '210 ppi density)', '401 ppi density)',
#        '294 ppi density)', '224 ppi density)', '267 ppi density)',
#        '283 ppi density)', '218 ppi density)', '189 ppi density)',
#        '149 ppi density)', '187 ppi density)', '233 ppi density)',
#        '245 ppi density)', '258 ppi density)', '196 ppi density)',
#        '216 ppi density)', '170 ppi density)', '312 ppi density)',
#        '402 ppi density)', '268 ppi density)', '282 ppi density)',
#        '293 ppi density)', '203 ppi density)', '424 ppi density)',
#        '423 ppi density)', '367 ppi density)', '534 ppi density)',
#        '121 ppi density)', '184 ppi density)', '278 ppi density)',
#        '201 ppi density)', '261 ppi density)', '287 ppi density)',
#        '141 ppi density)', '277 ppi density)', '339 ppi density)',
#        '252 ppi density)', '323 ppi density)', '254 ppi density)',
#        '143 ppi density)', '163 ppi density)', '182 ppi density)',
# ...

# %%
def fetch_num(text):
    text = str(text)
    text = text.split(' ')
    return text[0]

# %%
fetch_num('215 ppi density')
# Out:
# '215'

# %%
df
# Out:
#                            name  LTE            year  weight  \
# 0        Acer Chromebook Tab 10    0     2018, March  544.3
# 1            Acer Iconia Talk S    1    2016, August    260
# 2           Acer Liquid Z6 Plus    1    2016, August    169
# 3                Acer Liquid Z6    1    2016, August    126
# 4     Acer Iconia Tab 10 A3-A40    0     2016, April       -
# ...                         ...  ...             ...     ...
# 3024          ZTE nubia N1 lite    1  2017, February    171
# 3025          ZTE Blade V8 Mini    1  2017, February    141
# 3026          ZTE Blade V8 Lite    1  2017, February    136
# 3027          ZTE Blade A2 Plus    1  2017, February    189
# 3028                ZTE Hawkeye    1   2017, January       -
#
#                                     display_type  \
# 0     IPS LCD capacitive touchscreen, 16M colors
# 1     IPS LCD capacitive touchscreen, 16M colors
# 2     IPS LCD capacitive touchscreen, 16M colors
# ...

# %%
df['ppi_density'] = df['ppi_density'].apply(fetch_num)
df['ppi_density']
# Out:
# 0       264
# 1       210
# 2       401
# 3       294
# 4       224
#        ...
# 3024    267
# 3025    294
# 3026    294
# 3027    401
# 3028    401
# Name: ppi_density, Length: 3029, dtype: object

# %%
df
# Out:
#                            name  LTE            year  weight  \
# 0        Acer Chromebook Tab 10    0     2018, March  544.3
# 1            Acer Iconia Talk S    1    2016, August    260
# 2           Acer Liquid Z6 Plus    1    2016, August    169
# 3                Acer Liquid Z6    1    2016, August    126
# 4     Acer Iconia Tab 10 A3-A40    0     2016, April       -
# ...                         ...  ...             ...     ...
# 3024          ZTE nubia N1 lite    1  2017, February    171
# 3025          ZTE Blade V8 Mini    1  2017, February    141
# 3026          ZTE Blade V8 Lite    1  2017, February    136
# 3027          ZTE Blade A2 Plus    1  2017, February    189
# 3028                ZTE Hawkeye    1   2017, January       -
#
#                                     display_type  \
# 0     IPS LCD capacitive touchscreen, 16M colors
# 1     IPS LCD capacitive touchscreen, 16M colors
# 2     IPS LCD capacitive touchscreen, 16M colors
# ...

# %%
df['battery']
# Out:
# 0           Non-removable Li-Po 4500 mAh battery (34 Wh)
# 1       Non-removable Li-Ion 3400 mAh battery (12.92 Wh)
# 2                   Non-removable Li-Po 4080 mAh battery
# 3                      Removable Li-Ion 2000 mAh battery
# 4                  Non-removable Li-Ion 6100 mAh battery
#                               ...
# 3024               Non-removable Li-Ion 3000 mAh battery
# 3025               Non-removable Li-Ion 2800 mAh battery
# 3026               Non-removable Li-Ion 2500 mAh battery
# 3027               Non-removable Li-Ion 5000 mAh battery
# 3028                             Li-Ion 3000 mAh battery
# Name: battery, Length: 3029, dtype: object

# %%
def fetch_battery_size(text):
    text = str(text)
    if text.find('mAh') != -1:
        text = text.split('mAh')
        text = text[0].split()
        text = text[-1]
        return text
    
    else:
        return None

# %%
df['battery_size'] = df['battery'].apply(fetch_battery_size)

# %%
df['battery_size']
# Out:
# 0       4500
# 1       3400
# 2       4080
# 3       2000
# 4       6100
#         ...
# 3024    3000
# 3025    2800
# 3026    2500
# 3027    5000
# 3028    3000
# Name: battery_size, Length: 3029, dtype: object

# %%
df
# Out:
#                            name  LTE            year  weight  \
# 0        Acer Chromebook Tab 10    0     2018, March  544.3
# 1            Acer Iconia Talk S    1    2016, August    260
# 2           Acer Liquid Z6 Plus    1    2016, August    169
# 3                Acer Liquid Z6    1    2016, August    126
# 4     Acer Iconia Tab 10 A3-A40    0     2016, April       -
# ...                         ...  ...             ...     ...
# 3024          ZTE nubia N1 lite    1  2017, February    171
# 3025          ZTE Blade V8 Mini    1  2017, February    141
# 3026          ZTE Blade V8 Lite    1  2017, February    136
# 3027          ZTE Blade A2 Plus    1  2017, February    189
# 3028                ZTE Hawkeye    1   2017, January       -
#
#                                     display_type  \
# 0     IPS LCD capacitive touchscreen, 16M colors
# 1     IPS LCD capacitive touchscreen, 16M colors
# 2     IPS LCD capacitive touchscreen, 16M colors
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3029 entries, 0 to 3028
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              3029 non-null   object
#  1   LTE               3029 non-null   int64
#  2   year              3027 non-null   object
#  3   weight            3029 non-null   object
#  4   display_type      3026 non-null   object
#  5   screen_size       2712 non-null   object
#  6   ppi               3023 non-null   object
#  7   cpu_ghz           2213 non-null   object
#  8   ram               3029 non-null   object
#  9   internal          3029 non-null   object
#  10  camera            3026 non-null   object
#  11  front_cam         2716 non-null   object
#  12  blth_v            3028 non-null   object
#  13  battery           3028 non-null   object
#  14  price             1633 non-null   object
#  15  company           3029 non-null   object
# ...

# %%
df['year'] = df['year_rel']

# %%
df
# Out:
#                            name  LTE  year  weight  \
# 0        Acer Chromebook Tab 10    0  2018  544.3
# 1            Acer Iconia Talk S    1  2016    260
# 2           Acer Liquid Z6 Plus    1  2016    169
# 3                Acer Liquid Z6    1  2016    126
# 4     Acer Iconia Tab 10 A3-A40    0  2016       -
# ...                         ...  ...   ...     ...
# 3024          ZTE nubia N1 lite    1  2017    171
# 3025          ZTE Blade V8 Mini    1  2017    141
# 3026          ZTE Blade V8 Lite    1  2017    136
# 3027          ZTE Blade A2 Plus    1  2017    189
# 3028                ZTE Hawkeye    1  2017       -
#
#                                     display_type  \
# 0     IPS LCD capacitive touchscreen, 16M colors
# 1     IPS LCD capacitive touchscreen, 16M colors
# 2     IPS LCD capacitive touchscreen, 16M colors
# 3     IPS LCD capacitive touchscreen, 16M colors
# 4     IPS LCD capacitive touchscreen, 16M colors
# ...                                          ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3029 entries, 0 to 3028
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              3029 non-null   object
#  1   LTE               3029 non-null   int64
#  2   year              3029 non-null   object
#  3   weight            3029 non-null   object
#  4   display_type      3026 non-null   object
#  5   screen_size       2712 non-null   object
#  6   ppi               3023 non-null   object
#  7   cpu_ghz           2213 non-null   object
#  8   ram               3029 non-null   object
#  9   internal          3029 non-null   object
#  10  camera            3026 non-null   object
#  11  front_cam         2716 non-null   object
#  12  blth_v            3028 non-null   object
#  13  battery           3028 non-null   object
#  14  price             1633 non-null   object
#  15  company           3029 non-null   object
# ...

# %%
df_new = df[['year','LTE','ppi_density','screen_ratio_num','bluetooth','colors','screen_size_inch','camera_size','company','battery_size','front_cam','internal','ram','resolution',
             'processor_core']]

# %%
df_new
# Out:
#       year  LTE ppi_density screen_ratio_num bluetooth       colors  \
# 0     2018    0         264             4:3        4.1   16M colors
# 1     2016    1         210            16:9        4.0   16M colors
# 2     2016    1         401            16:9        4.0   16M colors
# 3     2016    1         294            16:9        4.0   16M colors
# 4     2016    0         224           16:10        4.0   16M colors
# ...    ...  ...         ...              ...       ...          ...
# 3024  2017    1         267            16:9        4.1   16M colors
# 3025  2017    1         294            16:9        4.1   16M colors
# 3026  2017    1         294            16:9        4.1   16M colors
# 3027  2017    1         401            16:9        4.0   16M colors
# 3028  2017    1         401            16:9        4.2   16M colors
#
#      screen_size_inch camera_size company battery_size front_cam     internal  \
# ...
